# %% [markdown]
# ### Напишите текстом как минимум 6 функций распределения и соответствующие им функции правдоподобия;
# ### Напишите, какие по вашему мнению целевые переменные из бизнеса (лучше - из страхового) соответствуют этим распределениям (по 2 примера на каждое);

# %% [markdown]
# # Распределения :

# %% [markdown]
# ## Дискретные распределения:

# %% [markdown]
# ### Распределение Бернулли
# $$P_n(k)=C_n^k \cdot p^k \cdot q^{n-k},  \quad q=1-p.$$

# %% [markdown]
# функции правдоподобия:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Биномиальное распределение
#
# ![image.png](attachment:image.png)

# %% [markdown]
# функции правдоподобия:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Геометрическое распределение
#
# ![image.png](attachment:image.png)

# %% [markdown]
# функции правдоподобия:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Распределения Пуассона:
#
# $$p(k;\lambda)=\frac{\lambda^k}{k!}\cdot e^{-\lambda}$$

# %% [markdown]
# функции правдоподобия:
# $$L(X;\lambda)=p(x_1;\lambda)\cdot p(x_2;\lambda)\cdot\ldots\cdot p(x_n;\lambda)$$

# %% [markdown]
# логарифм функции правдоподобия:
# $$\ln L(X;\lambda)=\ln p(x_1;\lambda)+\ln p(x_2;\lambda)+\ldots+ \ln p(x_n;\lambda)$$
# $$\ln L(X;\lambda)=\ln \lambda \cdot\sum_{k=1}^{n} x_k-n\cdot\lambda- \ln \Big(\prod_{k=1}^{n} x_n!\Big)$$

# %% [markdown]
# ## Абсолютно непрерывные распределения:

# %% [markdown]
# ### Распределением Гаусса (Нормальное распределение)
# ![image.png](attachment:image.png)

# %% [markdown]
# функции правдоподобия:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Равномерное распределение
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Экспоненциальное распределение

# %% [markdown]
# ### Распределение Коши
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Предсказание количества требований:
#
# биномиальное распределение
#
# распределение Пуассона
#
# отрицательно-биномиальное распределение

# %% [markdown]
# #### Для предсказания размера выплат
#
# экспоненциальное распределение
#
# нормальное распределение
#
# распределение Парето
#
# гамма-распределение
